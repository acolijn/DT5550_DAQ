# %% [markdown]
# ## Calibration of time offsets

# %%
import sys
sys.path.insert(0,'python/')

from Calibration import Calibration

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Process the selected data

# %%
# instantiate calibration class
myCal = Calibration(indir='C:/data/20220314_150101/')
# set the minimum energy to select event for time offset calibration
myCal.set_energy_min(1000)
# process the data
myCal.process_calibration_data(max_files=10)
# calculate the time offset calculations
myCal.calculate_time_offsets(plot=False, delta_time_max=20, write_config=True)
# Out:
# DT5550:: Data recorded with config:  C:/data/20220314_150101\config_20220314_150101.json
# Calibration:: Begin processing data....
# DT5550:: Open data file: C:/data/20220314_150101\data_20220314_150101_0.raw
# DT5550:: Open data file: C:/data/20220314_150101\data_20220314_150101_1.raw
# DT5550:: Open data file: C:/data/20220314_150101\data_20220314_150101_2.raw
# DT5550:: Open data file: C:/data/20220314_150101\data_20220314_150101_3.raw
# DT5550:: Open data file: C:/data/20220314_150101\data_20220314_150101_4.raw
# DT5550:: Open data file: C:/data/20220314_150101\data_20220314_150101_5.raw
# DT5550:: Open data file: C:/data/20220314_150101\data_20220314_150101_6.raw
# DT5550:: Open data file: C:/data/20220314_150101\data_20220314_150101_7.raw
# DT5550:: Open data file: C:/data/20220314_150101\data_20220314_150101_8.raw
# DT5550:: Open data file: C:/data/20220314_150101\data_20220314_150101_9.raw
# Calibration::calculate_time_offsets:: Done....
# calculate_time_offsets:: 0  dt = 0 ns
# calculate_time_offsets:: 1  dt = 0.816320798602531 ns
# calculate_time_offsets:: 2  dt = -0.40050665994598245 ns
# calculate_time_offsets:: 3  dt = 0.17571123876466635 ns
# calculate_time_offsets:: 4  dt = -1.2216992810000196 ns
# calculate_time_offsets:: 5  dt = 0.7177765220763602 ns
# calculate_time_offsets:: 6  dt = 0.37117946894002823 ns
# calculate_time_offsets:: 7  dt = 0.7886036193550617 ns
# write_calibration:: type = time_offset
# write_calibration:: calibration constants to  C:/data/20220314_150101\config_20220314_150101.json

# %% [markdown]
# #### Calculate the time offsets
#
# The offset is simply calculated from the mean of the distribution

# %%
myCal.plot_time_calibration()
