# %% [markdown]
# ## Calibration of time offsets

# %%
import sys
sys.path.insert(0,'python/')

from Calibration import Calibration

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Process the selected data

# %%
# instantiate calibration class
myCal = Calibration(indir='C:/data/20220307_122326/')
# set the minimum energy to select event for time offset calibration
myCal.set_energy_min(1000)
# process the data
myCal.process_calibration_data(max_files=5)
# calculate the time offset calculations
myCal.calculate_time_offsets(plot=False, delta_time_max=20, write_config=False)
# Out:
# DT5550:: Data recorded with config:  C:/data/20220307_122326\config_20220307_122326.json
# Calibration:: Begin processing data....
# DT5550:: Open data file: C:/data/20220307_122326\data_20220307_122326_0.raw
# DT5550:: Open data file: C:/data/20220307_122326\data_20220307_122326_1.raw
# DT5550:: Open data file: C:/data/20220307_122326\data_20220307_122326_2.raw
# DT5550:: Open data file: C:/data/20220307_122326\data_20220307_122326_3.raw
# DT5550:: Open data file: C:/data/20220307_122326\data_20220307_122326_4.raw
# Calibration::calculate_time_offsets:: Done....
# calculate_time_offsets:: 0  dt = 0 ns
# calculate_time_offsets:: 1  dt = 0.8782954455502363 ns
# calculate_time_offsets:: 2  dt = 0.37209322788981364 ns
# calculate_time_offsets:: 3  dt = 0.1174326085301965 ns
# calculate_time_offsets:: 4  dt = -0.8618891166107304 ns
# calculate_time_offsets:: 5  dt = 0.9017564539934152 ns
# calculate_time_offsets:: 6  dt = 0.21158856058408643 ns
# calculate_time_offsets:: 7  dt = 0.8127432078541044 ns

# %% [markdown]
# #### Calculate the time offsets
#
# The offset is simply calculated from the mean of the distribution

# %%
myCal.plot_time_calibration()
