# %% [markdown]
# ## Calibration of time offsets

# %%
import sys
sys.path.insert(0,'python/')

from Calibration import Calibration

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Process the selected data

# %%
# instantiate calibration class
myCal = Calibration(indir='C:/data/20220120_154253/')
# set the minimum energy to select event for time offset calibration
myCal.set_energy_min(0)
# process the data
myCal.process_calibration_data()
# calculate the time offset calculations
myCal.calculate_time_offsets(plot=False, delta_time_max=20, write_config=True)
# Out:
# DT5550:: Data recorded with config:  C:/data/20220120_154253\config_20220120_154253.json
# Calibration:: Begin processing data....
# DT5550:: Open data file: C:/data/20220120_154253\data_20220120_154253_0.raw
# DT5550:: Open data file: C:/data/20220120_154253\data_20220120_154253_1.raw
# Calibration::calculate_time_offsets:: Done....
# calculate_time_offsets:: 0  dt = 0 ns
# calculate_time_offsets:: 1  dt = -0.09480996756699515 ns
# calculate_time_offsets:: 2  dt = -0.38773871846112024 ns
# calculate_time_offsets:: 3  dt = -0.1794984293870789 ns
# calculate_time_offsets:: 4  dt = -0.18543072593273227 ns
# calculate_time_offsets:: 5  dt = -0.1845241164618338 ns
# calculate_time_offsets:: 6  dt = -0.11261233456834932 ns
# calculate_time_offsets:: 7  dt = 0.1626681439665247 ns
# write_calibration:: type = time_offset
# write_calibration:: calibration constants to  C:/data/20220120_154253\config_20220120_154253.json

# %% [markdown]
# #### Calculate the time offsets
#
# The offset is simply calculated from the mean of the distribution

# %%
myCal.plot_time_calibration()
