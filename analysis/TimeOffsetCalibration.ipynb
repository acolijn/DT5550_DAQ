# %% [markdown]
# ## Calibration of time offsets

# %%
import sys
sys.path.insert(0,'python/')

from Calibration import Calibration

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Process the selected data

# %%
# instantiate calibration class
myCal = Calibration(indir='C:/data/20220121_115544/')
# set the minimum energy to select event for time offset calibration
myCal.set_energy_min(0)
# process the data
myCal.process_calibration_data()
# calculate the time offset calculations
myCal.calculate_time_offsets(plot=False, delta_time_max=20, write_config=True)
# Out:
# DT5550:: Data recorded with config:  C:/data/20220121_115544\config_20220121_115544.json
# Calibration:: Begin processing data....
# DT5550:: Open data file: C:/data/20220121_115544\data_20220121_115544_0.raw
# Calibration::calculate_time_offsets:: Done....
# calculate_time_offsets:: 0  dt = 0 ns
# calculate_time_offsets:: 1  dt = 0.018163956614344556 ns
# calculate_time_offsets:: 2  dt = 0.0013591500177186247 ns
# calculate_time_offsets:: 3  dt = 0.049949604873021754 ns
# calculate_time_offsets:: 4  dt = -0.057995195144210636 ns
# calculate_time_offsets:: 5  dt = 0.004203893989650416 ns
# calculate_time_offsets:: 6  dt = -0.004482599169137151 ns
# calculate_time_offsets:: 7  dt = -0.04894225130826931 ns
# write_calibration:: type = time_offset
# write_calibration:: calibration constants to  C:/data/20220121_115544\config_20220121_115544.json

# %% [markdown]
# #### Calculate the time offsets
#
# The offset is simply calculated from the mean of the distribution

# %%
myCal.plot_time_calibration()
