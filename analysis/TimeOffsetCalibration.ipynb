# %% [markdown]
# ## Calibration of time offsets

# %%
import sys
sys.path.insert(0,'python/')

from Calibration import Calibration

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Process the selected data

# %%
# instantiate calibration class
myCal = Calibration(indir='../../data/20220104_153329/')
# set the minimum energy to select event for time offset calibration
myCal.set_energy_min(0)
# process the data
myCal.process_calibration_data()
# Out:
# DT5550:: Data recorded with config:  ../../data/20220104_153329\config_20220104_153329.json
# Calibration::calculate_time_offsets:: Begin....
# DT5550:: Open data file: ../../data/20220104_153329\data_20220104_153329_0.raw
# DT5550:: Open data file: ../../data/20220104_153329\data_20220104_153329_1.raw
# DT5550:: Open data file: ../../data/20220104_153329\data_20220104_153329_2.raw
# DT5550:: Open data file: ../../data/20220104_153329\data_20220104_153329_3.raw
# DT5550:: Open data file: ../../data/20220104_153329\data_20220104_153329_4.raw
# DT5550:: Open data file: ../../data/20220104_153329\data_20220104_153329_5.raw
# Calibration::calculate_time_offsets:: Done....

# %% [markdown]
# #### Calculate the time offsets
#
# The offset is simply calculated from the mean of the distribution

# %%
myCal.calculate_time_offsets(plot=True, delta_time_max=50, write_config=False)
# Out:
# calculate_time_offsets:: 0  dt = 0 ns
# calculate_time_offsets:: 1  dt = -1.0177923191120517 ns
# calculate_time_offsets:: 2  dt = -0.8587105768479201 ns
# calculate_time_offsets:: 3  dt = -1.1172196774675425 ns
# calculate_time_offsets:: 4  dt = -1.1713298059077446 ns
# calculate_time_offsets:: 5  dt = -1.5668910917648016 ns
# calculate_time_offsets:: 6  dt = -0.7050355341062732 ns
# calculate_time_offsets:: 7  dt = -1.7756590109195163 ns
# -50 50
# fit result [-2.76308828e-01  2.14594904e+04  4.28010177e+00]
