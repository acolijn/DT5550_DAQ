# %% [markdown]
# ### Calibration of peak / area ratio

# %%
import sys
sys.path.insert(0,'python/')

from Calibration import Calibration

import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

# %load_ext snakeviz

# %% [markdown]
# #### Process the selected data

# %%
# note: in order to maintain proper calibration constants all commends below should be run from within this cell)

# instantiate calibration class 
myCal = Calibration(file='C:/data/20220110_165917/data_20220110_165917_0.raw')
# myCal = Calibration(indir='../../data/20220104_154421/')
# process the data
#%snakeviz 
myCal.process_calibration_data()
# calculate the gain corrections
myCal.calculate_pulse_ratio(binwidth=10, plot=False, write_config=True)
# Out:
# DT5550:: Data recorded with config:  C:/data/20220110_165917\config_20220110_165917.json
# Calibration::calculate_time_offsets:: Begin....
# DT5550:: Open data file: C:/data/20220110_165917/data_20220110_165917_0.raw
# Calibration::calculate_time_offsets:: Done....
# calculate_pulse_ratio:: Calculate the mean pk/charge ratio
# 0  <R> =  1228.5257188170874  A =  7089.376900059108  sig =  14.790841337774614
# 1  <R> =  1262.7022576456782  A =  3576.946442264789  sig =  17.204479164288443
# 2  <R> =  1264.8941724404026  A =  4707.703054857062  sig =  15.525182599268952
# 3  <R> =  1262.837965573876  A =  4115.196647468555  sig =  -19.50253531008122
# 4  <R> =  1243.0363710386691  A =  5235.738519862977  sig =  17.092023834224054
# 5  <R> =  1192.5886811204807  A =  4734.161121010586  sig =  -17.263635503027285
# 6  <R> =  1265.4486135084192  A =  4647.354705879109  sig =  -16.10757027607575
# 7  <R> =  1263.0606965797353  A =  4083.897971244262  sig =  16.9881739264935
# write_calibration:: type = ratio
# write_calibration:: calibration constants to  C:/data/20220110_165917\config_20220110_165917.json

# %% [markdown]
# #### Plot the ratio distributions

# %%
myCal.plot_ratio_calibration(range=(1000,2000))
