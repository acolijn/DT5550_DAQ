# %% [markdown]
# ### Calibration of peak / area ratio

# %%
import sys
sys.path.insert(0,'python/')

from Calibration import Calibration

import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

# %load_ext snakeviz

# %% [markdown]
# #### Process the selected data

# %%
# note: in order to maintain proper calibration constants all commends below should be run from within this cell)

# instantiate calibration class 

#################### myCal = Calibration(file='C:/data/20220110_165917/data_20220110_165917_0.raw')
myCal = Calibration(indir='C:/data/20220210_104304/')
# myCal = Calibration(indir='../../data/20220104_154421/')
# process the data
#%snakeviz 
myCal.process_calibration_data()
# calculate the gain corrections
myCal.calculate_pulse_ratio(binwidth=10, plot=False, write_config=True)
# Out:
# DT5550:: Data recorded with config:  C:/data/20220210_104304\config_20220210_104304.json
# Calibration:: Begin processing data....
# DT5550:: Open data file: C:/data/20220210_104304\data_20220210_104304_0.raw
# DT5550:: Open data file: C:/data/20220210_104304\data_20220210_104304_1.raw
# DT5550:: Open data file: C:/data/20220210_104304\data_20220210_104304_2.raw
# DT5550:: Open data file: C:/data/20220210_104304\data_20220210_104304_3.raw
# DT5550:: Open data file: C:/data/20220210_104304\data_20220210_104304_4.raw
# DT5550:: Open data file: C:/data/20220210_104304\data_20220210_104304_5.raw
# DT5550:: Open data file: C:/data/20220210_104304\data_20220210_104304_6.raw
# Calibration::calculate_time_offsets:: Done....
# calculate_pulse_ratio:: Calculate the mean pk/charge ratio
# 0  <R> =  1219.6152740631771  A =  61757.250597292834  sig =  14.193594181215945
# 1  <R> =  1250.4662532613263  A =  50956.11526790478  sig =  16.32870716243357
# 2  <R> =  1256.9039193222106  A =  49733.58439425225  sig =  15.294958733499747
# 3  <R> =  1253.9793220896136  A =  40555.079095563546  sig =  17.71288570121083
# 4  <R> =  1221.9167756234008  A =  52025.29760096792  sig =  17.71009356190914
# 5  <R> =  1179.5310936133078  A =  52639.04021419045  sig =  15.823355282467402
# 6  <R> =  1253.642662594244  A =  49759.92290616656  sig =  16.085012769129218
# 7  <R> =  1253.0293254739038  A =  44210.74459202499  sig =  16.750710227840727
# write_calibration:: type = ratio
# write_calibration:: calibration constants to  C:/data/20220210_104304\config_20220210_104304.json

# %% [markdown]
# #### Plot the ratio distributions

# %%
myCal.plot_ratio_calibration(range=(000,2500), yscale='log')
