# %% [markdown]
# ### Calibration of peak / area ratio

# %%
import sys
sys.path.insert(0,'python/')

from Calibration import Calibration

import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

# %load_ext snakeviz

# %% [markdown]
# #### Process the selected data

# %%
# note: in order to maintain proper calibration constants all commends below should be run from within this cell)

# instantiate calibration class 

#################### myCal = Calibration(file='C:/data/20220110_165917/data_20220110_165917_0.raw')
myCal = Calibration(indir='C:/data/20220113_165922/')
# myCal = Calibration(indir='../../data/20220104_154421/')
# process the data
#%snakeviz 
myCal.process_calibration_data()
# calculate the gain corrections
myCal.calculate_pulse_ratio(binwidth=10, plot=False, write_config=True)
# Out:
# DT5550:: Data recorded with config:  C:/data/20220113_165922\config_20220113_165922.json
# Calibration::calculate_time_offsets:: Begin....
# DT5550:: Open data file: C:/data/20220113_165922\data_20220113_165922_0.raw
# DT5550:: Open data file: C:/data/20220113_165922\data_20220113_165922_1.raw
# DT5550:: Open data file: C:/data/20220113_165922\data_20220113_165922_4.raw
# DT5550:: Open data file: C:/data/20220113_165922\data_20220113_165922_5.raw
# Calibration::calculate_time_offsets:: Done....
# calculate_pulse_ratio:: Calculate the mean pk/charge ratio
# 0  <R> =  1229.2744542642715  A =  34246.73631859451  sig =  17.517180242954943
# 1  <R> =  1262.307612936855  A =  20595.33718891384  sig =  20.519392057545048
# 2  <R> =  1265.15716745176  A =  29782.652205039165  sig =  18.045186955680244
# 3  <R> =  1262.0189695517045  A =  25214.5483479362  sig =  22.66256630824887
# 4  <R> =  1241.447577074436  A =  28502.08165726168  sig =  20.661231978693824
# 5  <R> =  1191.608198163733  A =  27353.507699800997  sig =  20.033687002905538
# 6  <R> =  1265.530336089255  A =  28802.988486830352  sig =  19.09898899156064
# 7  <R> =  1267.0166016844378  A =  20570.61554410967  sig =  20.351395337861312
# write_calibration:: type = ratio
# write_calibration:: calibration constants to  C:/data/20220113_165922\config_20220113_165922.json

# %% [markdown]
# #### Plot the ratio distributions

# %%
myCal.plot_ratio_calibration(range=(000,2500), yscale='log')
